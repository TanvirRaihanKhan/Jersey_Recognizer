# %%
# !pip install -Uqq fastai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.8/232.8 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 14.5 MB/s eta 0:00:00

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Mastercourse/Jersey Recogniser
# Out:
# /content/drive/My Drive/Mastercourse/Jersey Recogniser

# %%
version=2
img_path="Test Data"
model_path=f"checkpoints/models/jersey-recogniser-v{version}.pkl"

# %%
model=load_learner(model_path)

# %% [markdown]
# # Inference 1

# %% [markdown]
# Target:Napoli jersey

# %%
img=Image.open(f"{img_path}/Test_image1.jpg")
img.to_thumb(192,192)
# Out:
# <PIL.Image.Image image mode=RGB size=170x192>

# %%
model.predict(f"{img_path}/Test_image1.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Napoly Jersey',
#  tensor(14),
#  tensor([7.6699e-08, 3.3051e-06, 2.7777e-05, 1.9672e-06, 1.6960e-08, 3.3415e-08,
#          7.2596e-06, 2.6045e-07, 6.9265e-07, 9.6632e-07, 5.8213e-08, 1.2290e-07,
#          6.2681e-06, 3.7335e-08, 9.9954e-01, 8.3403e-05, 3.2827e-04, 1.4423e-07,
#          5.4964e-08, 3.4495e-07]))

# %% [markdown]
# # Inference 2

# %% [markdown]
# Target: Barcelona jersey

# %%
img=Image.open(f"{img_path}/Test_image2.jpg")
img.to_thumb(192,192)
# Out:
# <PIL.Image.Image image mode=RGB size=192x192>

# %%
model.predict(f"{img_path}/Test_image2.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Barcelona Jersey',
#  tensor(3),
#  tensor([1.8950e-06, 8.0021e-05, 7.8851e-05, 9.9602e-01, 1.8994e-05, 1.2282e-04,
#          3.3127e-06, 1.4410e-04, 3.1103e-06, 3.4481e-05, 2.5451e-06, 4.3574e-05,
#          1.0491e-06, 3.3097e-06, 1.5292e-05, 4.4673e-05, 4.1538e-07, 1.0476e-06,
#          3.3764e-03, 1.4334e-06]))

# %% [markdown]
# # Inference 3

# %% [markdown]
# Target: Chelsea jersey

# %%
img=Image.open(f"{img_path}/Test_image3.jpg")
img.to_thumb(192,192)
# Out:
# <PIL.Image.Image image mode=RGB size=140x192>

# %%
model.predict(f"{img_path}/Test_image3.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Chelsea Jersey',
#  tensor(6),
#  tensor([5.0318e-07, 2.3949e-07, 3.6435e-07, 8.8154e-07, 3.9980e-06, 2.2537e-07,
#          9.9970e-01, 4.2068e-07, 9.4775e-07, 2.7202e-08, 9.8121e-06, 4.3814e-06,
#          4.4135e-05, 2.0285e-06, 2.5270e-06, 3.7020e-06, 2.2055e-04, 8.0709e-07,
#          1.7112e-06, 1.2360e-07]))

# %% [markdown]
# # Inference 4

# %% [markdown]
# Target: :Liverpool jersey

# %%
img=Image.open(f"{img_path}/Test_image4.jpg")
img.to_thumb(192,192)
# Out:
# <PIL.Image.Image image mode=RGB size=192x154>

# %%
model.predict(f"{img_path}/Test_image4.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Liverpool Jersey',
#  tensor(11),
#  tensor([5.2050e-08, 4.0909e-07, 1.9032e-07, 1.3465e-06, 2.5978e-07, 1.8541e-09,
#          8.0126e-07, 9.3790e-09, 6.8177e-09, 3.2087e-08, 6.3485e-06, 9.9992e-01,
#          5.1697e-07, 7.6071e-07, 5.1473e-07, 2.5051e-06, 4.1638e-08, 2.6594e-07,
#          6.5502e-05, 8.0801e-08]))
